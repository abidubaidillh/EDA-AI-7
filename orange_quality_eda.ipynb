# %% [markdown]
# ## Tugas AI 🤖
# #### 5027231041 5027231051 5027231085 5027231089
# # 📊EDA
#
# **EDA (Exploratory Data Analysis)** atau Analisis Data Eksploratif adalah teknik untuk memahami dan menjelajahi data sebelum melakukan analisis lebih lanjut. Tujuannya adalah untuk menemukan pola, anomali, hubungan antar variabel, dan mendapatkan wawasan awal dari data.
#
# (note : menggunakan tabular dataset **Orange Quality**🍊)

# %% [markdown]
# ### Memuat Dataset ke Jupyter Notebook
#
# 1. Import Library :
# - Pandas
# - Matplotlib
# - Seaborn
# - Numpy

# %%
# import requirements library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Baca Dataset :
# - Gunakan pandas untuk membaca dataset (misalnya, file CSV):

# %%
df = pd.read_csv("Orange Quality Data.csv")

# %% [markdown]
# 3. Cek Data :
# - Menampilkan 5 data pertama

# %%
df.head()  # Menampilkan 5 baris pertama

# %% [markdown]
# - Menampilkan jumlah baris & kolom

# %%
# get the shape of the dataset
df.shape
# Out:
# (241, 11)

# %% [markdown]
# - Melihat tipe data dan jumlah nilai yang null

# %%
# get the info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Size (cm)           241 non-null    float64
#  1   Weight (g)          241 non-null    int64
#  2   Brix (Sweetness)    241 non-null    float64
#  3   pH (Acidity)        241 non-null    float64
#  4   Softness (1-5)      241 non-null    float64
#  5   HarvestTime (days)  241 non-null    int64
#  6   Ripeness (1-5)      241 non-null    float64
#  7   Color               241 non-null    object
#  8   Variety             241 non-null    object
#  9   Blemishes (Y/N)     241 non-null    object
#  10  Quality (1-5)       241 non-null    float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 20.8+ KB

# %% [markdown]
# - Cek statistik deskriptif

# %%
# get statistical summary
df.describe()
# Out:
# (241, 11)

# %% [markdown]
# 2. Cek missing values (memeriksa jumlah nilai yang hilang dalam setiap kolom)

# %%
# checking missing values
df.isnull().sum()
# Out:
# Size (cm)             0
# Weight (g)            0
# Brix (Sweetness)      0
# pH (Acidity)          0
# Softness (1-5)        0
# HarvestTime (days)    0
# Ripeness (1-5)        0
# Color                 0
# Variety               0
# Blemishes (Y/N)       0
# Quality (1-5)         0
# dtype: int64

# %%
# checking duplicate
data_nd = df.drop_duplicates(subset = "Variety")
data_nd
# Out:
#     Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0         7.5         180              12.0           3.2             2.0
# 1         8.2         220              10.5           3.4             3.0
# 2         6.8         150              14.0           3.0             1.0
# 3         9.0         250               8.5           3.8             4.0
# 4         8.5         210              11.5           3.3             2.5
# 6         7.2         160               9.0           3.5             3.5
# 7         6.5         130              13.5           2.8             1.5
# 8         8.8         240               7.5           4.0             5.0
# 9         7.8         190              12.0           3.1             2.0
# 12        8.0         200              10.0           3.5             3.0
# 13        7.0         140              11.0           3.2             2.5
# 14        9.2         260               9.5           3.7             4.5
# ...

# %%
# checking balance label
df.value_counts("Variety")
# Out:
# Variety
# Cara Cara                21
# Temple                   18
# Star Ruby                18
# Moro (Blood)             16
# Navel                    16
# Clementine               14
# Tangerine                14
# Washington Navel         14
# Satsuma Mandarin         13
# Ortanique (Hybrid)       13
# Minneola (Hybrid)        12
# Jaffa                    11
# Valencia                 11
# Ambiance                 11
# California Valencia       7
# Honey Tangerine           7
# Hamlin                    5
# Midsweet (Hybrid)         5
# Clementine (Seedless)     4
# Murcott (Hybrid)          3
# Navel (Late Season)       3
# Blood Orange              2
# Navel (Early Season)      2
# Tangelo (Hybrid)          1
# Name: count, dtype: int64

# %%
# visualize each label
plt.figure(figsize=(12, 6))  # Perbesar ukuran figure
sns.countplot(x='Variety', data=df)
plt.xticks(rotation=45, ha="right")  # Rotasi label agar lebih jelas
plt.show()

# %%
# Relation between variables
sns.scatterplot(x='Size (cm)', y='Weight (g)',
                hue='Variety', data=df, )
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
# Relation between variables
sns.scatterplot(x='Quality (1-5)', y='Brix (Sweetness)',
                hue='Variety', data=df, )
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
# Relation between variables
sns.scatterplot(x='Brix (Sweetness)', y='HarvestTime (days)',
                hue='Variety', data=df, )
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
# plot all the columns' relationship
sns.pairplot(df, hue='Variety', height=2)

# %%
# Histogram with Displot
plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "Size (cm)").add_legend()

plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "Weight (g)").add_legend()
 
plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "Brix (Sweetness)").add_legend()
 
plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "pH (Acidity)").add_legend()

plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "Softness (1-5)").add_legend()

plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "HarvestTime (days)").add_legend()

plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "Ripeness (1-5)").add_legend()

plot = sns.FacetGrid(df, hue="Variety")
plot.map(sns.distplot, "Quality (1-5)").add_legend()
 
plt.show()
# Out:
# c:\Users\syahmi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\syahmi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# Pilih hanya kolom numerik sebelum menghitung korelasi
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr(method='pearson')
print(correlation_matrix)
# Out:
#                     Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  \
# Size (cm)            1.000000    0.305348         -0.305865      0.330487
# Weight (g)           0.305348    1.000000         -0.239659      0.303806
# Brix (Sweetness)    -0.305865   -0.239659          1.000000     -0.300080
# pH (Acidity)         0.330487    0.303806         -0.300080      1.000000
# Softness (1-5)       0.236863    0.316806         -0.344376      0.360222
# HarvestTime (days)   0.313330    0.374670         -0.329862      0.262461
# Ripeness (1-5)      -0.256665   -0.260454          0.144666     -0.232627
# Quality (1-5)       -0.243113   -0.330268          0.631343     -0.321942
#
#                     Softness (1-5)  HarvestTime (days)  Ripeness (1-5)  \
# Size (cm)                 0.236863            0.313330       -0.256665
# Weight (g)                0.316806            0.374670       -0.260454
# Brix (Sweetness)         -0.344376           -0.329862        0.144666
# ...

# %%
# Pilih hanya kolom numerik
numeric_data = df.select_dtypes(include=['number'])
# Buat heatmap
sns.heatmap(numeric_data.corr(method='pearson'), annot=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def graph(y):
    sns.boxplot(x="Variety", y=y, data=df)
    plt.xticks(rotation=45)  # Memiringkan label jika kategori banyak
    plt.title(f"Boxplot of {y} by Variety")  # Menambahkan judul tiap grafik

# List kolom numerik yang ingin diplot
numerical_cols = ["Size (cm)", "Weight (g)", "Brix (Sweetness)", 
                  "Softness (1-5)", "HarvestTime (days)", 
                  "Ripeness (1-5)", "Quality (1-5)"]

# Menentukan jumlah baris dan kolom subplot
n_rows = (len(numerical_cols) // 3) + 1  # Maksimal 3 kolom per baris
fig, axes = plt.subplots(n_rows, 3, figsize=(20, n_rows * 5))

# Loop untuk membuat boxplot
for i, col in enumerate(numerical_cols):
    row, col_index = divmod(i, 3)  # Hitung posisi berdasarkan indeks
    plt.sca(axes[row, col_index])  # Pindah ke subplot yang sesuai
    graph(col)

# Menghapus subplot kosong agar tampilan lebih rapi
for j in range(i+1, n_rows * 3):  
    fig.delaxes(axes.flatten()[j])

plt.tight_layout()  # Menghindari tumpang tindih
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='pH (Acidity)', data=df)
plt.xticks(rotation=45)  # Memiringkan label jika banyak kategori
plt.title("Distribution of Variety")
plt.show()
